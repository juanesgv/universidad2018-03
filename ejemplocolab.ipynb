# %% [markdown]
# <a href="https://colab.research.google.com/github/juanesgv/universidad2018-03/blob/master/ejemplocolab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# prueba

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#importar librerias necesarias
import numpy as np
import matplotlib.pyplot as plt
import cv2
#graficar imagenes estaticas en el notebook
# %matplotlib inline

# %%
image = cv2.imread('/content/drive/My drive/procesamiento digital de imagenes/sagrado-corazon-jesus.jpg')
cv2.imshow('Image',image)
cv2.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# DisabledFunctionError                     Traceback (most recent call last)
# <ipython-input-15-33ef3e197c03> in <module>()
#       1 image = cv2.imread('/content/drive/My drive/procesamiento digital de imagenes/sagrado-corazon-jesus.jpg')
# ----> 2 cv2.imshow('Image',image)
#       3 cv2.waitKey(0)
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_import_hooks/_cv2.py in wrapped(*args, **kwargs)
#      50   def wrapped(*args, **kwargs):
#      51     if not os.environ.get(env_var, False):
# ---> 52       raise DisabledFunctionError(message, name or func.__name__)
#      53     return func(*args, **kwargs)
#      54
#
# DisabledFunctionError: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow

# %%
from google.colab.patches import cv2_imshow
img = cv2.imread(C, cv2.IMREAD_UNCHANGED)
cv2_imshow(img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-9378536f762a> in <module>()
#       1 from google.colab.patches import cv2_imshow
#       2 img = cv2.imread('/content/drive/My drive/procesamiento digital de imagenes/sagrado-corazon-jesus.jpg', cv2.IMREAD_UNCHANGED)
# ----> 3 cv2_imshow(img)
#
# /usr/local/lib/python3.6/dist-packages/google/colab/patches/__init__.py in cv2_imshow(a)
#      20       image.
#      21   """
# ---> 22   a = a.clip(0, 255).astype('uint8')
#      23   # cv2 stores colors as BGR; convert to RGB
#      24   if a.ndim == 3:
#
# AttributeError: 'NoneType' object has no attribute 'clip'

# %%
img_BGR = cv2.imread('/content/drive/My drive/imagenes/JESUS.jpg',cv2.IMREAD_COLOR)

plt.figure(figsize=(7,7))
plt.imshow(img_BGR)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-e16cf0830d27> in <module>()
#       2
#       3 plt.figure(figsize=(7,7))
# ----> 4 plt.imshow(img_BGR)
#       5 plt.show()
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2697         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2698         resample=resample, url=url, **({"data": data} if data is not
# -> 2699         None else {}), **kwargs)
#    2700     sci(__ret)
#    2701     return __ret
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
# ...

# %%
# !pwd
# Out:
# /content

# %%
# !ls
# Out:
# sample_data

# %%
# %cd /content/drive/My Drive/imagenes
# Out:
# /content/drive/My Drive/imagenes

# %%
# !pwd
# Out:
# /content/drive/My Drive/imagenes

# %%
from google.colab.patches import cv2_imshow
img = cv2.imread('JESUS.jpg',cv2.IMREAD_UNCHANGED)
img = cv2.resize(img,(int(300),int(300)))
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7F8A177BB978>

# %%
import os

path = '/content/drive/My Drive/imagenes'
os.chdir(path)
# !pwd

from google.colab.patches import cv2_imshow
img = cv2.imread('JESUS.jpg',cv2.IMREAD_UNCHANGED)
img = cv2.resize(img,(int(300),int(300)))
cv2_imshow(img)
# Out:
# /content/drive/My Drive/imagenes
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7F8A1774DC18>

# %%
img_BGR = cv2.imread('/content/drive/My drive/imagenes/JESUS.jpg',cv2.IMREAD_COLOR)

plt.figure(figsize=(7,7))
plt.imshow(img_BGR)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-e16cf0830d27> in <module>()
#       2
#       3 plt.figure(figsize=(7,7))
# ----> 4 plt.imshow(img_BGR)
#       5 plt.show()
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2697         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2698         resample=resample, url=url, **({"data": data} if data is not
# -> 2699         None else {}), **kwargs)
#    2700     sci(__ret)
#    2701     return __ret
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
# ...

# %%
print (img.shape)
res = cv2.resize(img, None,fx=10, fy=10, interpolation = cv2.INTER_CUBIC)
print(res.shape)
plt.imshow(res)
plt.show()
# Out:
# (300, 300, 3)
# (3000, 3000, 3)

# %%
print (img.shape)
res = cv2.resize(img, None,fx=.1, fy=.1, interpolation = cv2.INTER_CUBIC)
print(res.shape)
plt.imshow(res)
plt.show()

# %%
print (res.shape)
plt.imshow(res)
plt.xticks([])
plt.yticks([])
plt.show()
# Out:
# (30, 30, 3)

# %%
img_RGB =cv2.cvtColor(img_BGR,cv2.COLOR_BGR2RGB)

plt.figure(figsize=(10,10))
plt.imshow(img_RGB)
plt.xticks([])
plt.yticks([])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-35-cb1b03a18dc6> in <module>()
# ----> 1 img_RGB =cv2.cvtColor(img_BGR,cv2.COLOR_BGR2RGB)
#       2
#       3 plt.figure(figsize=(10,10))
#       4 plt.imshow(img_RGB)
#       5 plt.xticks([])
#
# error: OpenCV(3.4.3) /io/opencv/modules/imgproc/src/color.cpp:181: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
img_GRAY =cv2.cvtColor(img_BGR,cv2.COLOR_BGR2GRAY)

plt.figure(figsize=(10,10))
plt.imshow(img_GRAY,cmap='gray')
plt.xticks([])
plt.yticks([])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-28-0e2f375094bd> in <module>()
# ----> 1 img_GRAY =cv2.cvtColor(img_BGR,cv2.COLOR_BGR2GRAY)
#       2
#       3 plt.figure(figsize=(10,10))
#       4 plt.imshow(img_GRAY,cmap='gray')
#       5 plt.xticks([])
#
# error: OpenCV(3.4.3) /io/opencv/modules/imgproc/src/color.cpp:181: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %% [markdown]
# **usar metodos para mostrar imagenes**

# %%
def display(a,b, title1 = "Original",title2="Edited"):
    plt.figure(figsize=(14,14))
    plt.subplot(121), plt.imshow(a), plt.title(title1)
    plt.xticks([]), plt.xticks([])
    plt.subplot(122), plt.imshow(b), plt.title(title2)
    plt.xticks([]), plt.yticks([])
    plt.show()

def display_one (a,title1= "Original1"):
    plt.imshow(a), plt.title(title1)
    plt.xticks([]), plt.yticks([])
    plt.show()

display_one(res)
display(res,res)
